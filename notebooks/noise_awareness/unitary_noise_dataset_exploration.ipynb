# %% [markdown]
# # Noise-Aware Dataset Exploration
#
# This notebook inspects a derived noise-aware unitary-compilation dataset.
#
# It focuses on:
# - whether `noise_p` was saved correctly
# - how many rows exist per noise level
# - how circuit lengths shift across the relabeled dataset

# %%
import os
import sys
from pathlib import Path

from IPython.display import display

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from notebooks.noise_awareness.unitary_noise_common import maybe_dataframe
from notebooks.noise_awareness.unitary_noise_dataset_exploration_helper import (
    analyze_noise_dataset,
    plot_noise_dataset_summary,
)

# %%
DATASET_PATH = Path("./datasets/noise_aware/unitary_3q_quditkit_noise_v1")
DEVICE = "cpu"

print("DATASET_PATH =", DATASET_PATH)

# %%
analysis = analyze_noise_dataset(DATASET_PATH, device=DEVICE)
display(maybe_dataframe(analysis["overview"]))

# %%
display(maybe_dataframe(analysis["noise_rows"]))

# %%
plot_noise_dataset_summary(analysis)
